# %% [markdown]
# <a href="https://colab.research.google.com/github/mirerodrigues/projeto-analise-dados/blob/main/novo-grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importacao de bibliotecas
import random
import matplotlib.pyplot as plt

# Gerar uma lista com 10 números aleatórios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

# Exibir a lista gerada
print('Lista de dados', dados)

# Plotar os dados
plt.plot(dados, marker='o')  # marcador em cada ponto para melhor visualização
plt.title('Grafico de Números Aleatórios')
plt.xlabel('Indice')
plt.ylabel('Valor')
plt.grid(True)
plt.show()
# Out:
# Lista de dados [83, 84, 83, 75, 29, 29, 19, 15, 38, 43]
